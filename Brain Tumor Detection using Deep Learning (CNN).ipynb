# %% [markdown]
# ## Importing Important Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import tensorflow as tf
import cv2

# %% [markdown]
# ## Data Visualisation

# %%
def plot_images(direction):  
    list_direction=os.listdir(direction)

    plt.figure(figsize=(16,10))

    for i in range(1,10):
        plt.subplot(3,3,i)
        img=plt.imread(os.path.join(direction,list_direction[i]))
        plt.imshow(img)

# %% [markdown]
# #### Glioma Tumor

# %%
glioma_tumor_dir="../input/brain-tumor-classification-mri/Training/glioma_tumor"
plot_images(glioma_tumor_dir)

# %% [markdown]
# #### Meningioma Tumor

# %%
meningioma_tumor_dir="../input/brain-tumor-classification-mri/Training/meningioma_tumor"
plot_images(meningioma_tumor_dir)

# %% [markdown]
# #### No Tumor

# %%
no_tumor_dir="../input/brain-tumor-classification-mri/Training/no_tumor"
plot_images(no_tumor_dir)

# %% [markdown]
# #### Pituitary Tumor

# %%
pituitary_tumor_dir="../input/brain-tumor-classification-mri/Training/pituitary_tumor"
plot_images(pituitary_tumor_dir)

# %% [markdown]
# ## Preprocessing

# %%
X_train = []
y_train = []
image_size = 150
labels = ["glioma_tumor","no_tumor","meningioma_tumor","pituitary_tumor"]
for i in labels:
    folderPath = os.path.join("../input/brain-tumor-classification-mri/Training",i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join("../input/brain-tumor-classification-mri/Testing",i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %%
y_train.shape
# Out:
# (3264,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_train,y_train,test_size=.1,random_state=0)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

# %%
y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ## Model

# %%
model = keras.Sequential([
        keras.layers.Conv2D(filters=100, kernel_size=(5,5), activation='relu', input_shape=(150,150, 3)),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Conv2D(filters=500, kernel_size=(5,5), activation='relu'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(500, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(100, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(4, activation="sigmoid")    
    ])

model.compile(optimizer="SGD",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 92/92 [==============================] - 9s 94ms/step - loss: 1.2337 - accuracy: 0.4501
# Epoch 2/50
# 92/92 [==============================] - 7s 80ms/step - loss: 1.0833 - accuracy: 0.5499
# Epoch 3/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.9302 - accuracy: 0.6176
# Epoch 4/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.8150 - accuracy: 0.6806
# Epoch 5/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.7205 - accuracy: 0.7160
# Epoch 6/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.6134 - accuracy: 0.7586
# Epoch 7/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.5657 - accuracy: 0.7814
# Epoch 8/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.4803 - accuracy: 0.8226
# Epoch 9/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.4093 - accuracy: 0.8478
# Epoch 10/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.3879 - accuracy: 0.8563
# Epoch 11/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.3116 - accuracy: 0.8893
# Epoch 12/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.2521 - accuracy: 0.9064
# Epoch 13/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.2090 - accuracy: 0.9275
# Epoch 14/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.1684 - accuracy: 0.9421
# Epoch 15/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.1544 - accuracy: 0.9527
# Epoch 16/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.1175 - accuracy: 0.9629
# Epoch 17/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.1032 - accuracy: 0.9694
# Epoch 18/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0913 - accuracy: 0.9707
# Epoch 19/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0695 - accuracy: 0.9796
# Epoch 20/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0658 - accuracy: 0.9803
# Epoch 21/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0533 - accuracy: 0.9847
# Epoch 22/50
# 92/92 [==============================] - 7s 79ms/step - loss: 0.0621 - accuracy: 0.9796
# Epoch 23/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0370 - accuracy: 0.9901
# Epoch 24/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0370 - accuracy: 0.9922
# Epoch 25/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0198 - accuracy: 0.9952
# Epoch 26/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0263 - accuracy: 0.9949
# Epoch 27/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0241 - accuracy: 0.9946
# Epoch 28/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0928 - accuracy: 0.9772
# Epoch 29/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0343 - accuracy: 0.9922
# Epoch 30/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0256 - accuracy: 0.9935
# Epoch 31/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0201 - accuracy: 0.9949
# Epoch 32/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 33/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0162 - accuracy: 0.9966
# Epoch 34/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0176 - accuracy: 0.9963
# Epoch 35/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0124 - accuracy: 0.9976
# Epoch 36/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0142 - accuracy: 0.9969
# Epoch 37/50
# 92/92 [==============================] - 7s 79ms/step - loss: 0.0079 - accuracy: 0.9983
# Epoch 38/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0128 - accuracy: 0.9976
# Epoch 39/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0075 - accuracy: 0.9983
# Epoch 40/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 41/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 42/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0071 - accuracy: 0.9990
# Epoch 43/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0108 - accuracy: 0.9980
# Epoch 44/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0100 - accuracy: 0.9963
# Epoch 45/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0056 - accuracy: 0.9993
# Epoch 46/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 47/50
# 92/92 [==============================] - 7s 81ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 48/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 49/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 50/50
# 92/92 [==============================] - 7s 80ms/step - loss: 0.0050 - accuracy: 0.9990

# %% [markdown]
# ## Evaluate the Model

# %%
model.evaluate(X_test,y_test)
# Out:
# 11/11 [==============================] - 1s 54ms/step - loss: 0.4964 - accuracy: 0.9021
# [0.49643033742904663, 0.9021406769752502]

# %% [markdown]
# #### Accuracy of testing dataset is 90.21%
